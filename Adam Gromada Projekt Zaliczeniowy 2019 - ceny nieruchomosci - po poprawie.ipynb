# %% [markdown]
# # Adam Gromada
# Projekt zaliczeniowy - Data Science ING
#
# Prognozowanie cen nieruchomosci mieszkalnych

# %% [markdown]
#     Import bibliotek

# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn import metrics

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV

import matplotlib.pyplot as plt

# %% [markdown]
#     Import danych

# %%
df = pd.read_csv('ames2000_NAfix.csv')

# %%
pd.set_option('display.max_columns', 80)
df.head(10)
# Out:
#    MS.SubClass MS.Zoning Lot.Frontage  Lot.Area Street Alley Lot.Shape  \
# 0          120        RL           34      3901   Pave  None       Reg
# 1           20        RL           70      8400   Pave  None       Reg
# 2           85        RL           60      7200   Pave  None       Reg
# 3           90        RL           64      7018   Pave  None       Reg
# 4           60        RL          111     16259   Pave  None       Reg
# 5           20        RL           50      4280   Pave  None       IR1
# 6           20        RL          155     20064   Pave  None       IR1
# 7           20        RM           60      7200   Pave  Grvl       Reg
# 8           20        RL           70      9100   Pave  None       Reg
# 9           70   C (all)         None      6449   Pave  None       IR1
#
#   Land.Contour Utilities Lot.Config Land.Slope Neighborhood Condition.1  \
# 0          Lvl    AllPub     Inside        Gtl      NridgHt        Norm
# 1          Lvl    AllPub     Corner        Gtl      Nonemes        Norm
# 2          Lvl    AllPub     Inside        Gtl      CollgCr        Norm
# 3          Bnk    AllPub     Inside        Gtl      SawyerW        Norm
# 4          Lvl    AllPub     Corner        Gtl      NridgHt        Norm
# 5          Lvl    AllPub     Inside        Gtl       Sawyer        Norm
# 6          Low    AllPub     Inside        Sev      ClearCr        Norm
# 7          Lvl    AllPub     Inside        Gtl      OldTown        Norm
# 8          Lvl    AllPub     Inside        Gtl      CollgCr        Norm
# 9          Lvl    AllPub     Inside        Gtl        SWISU        Norm
#
#   Condition.2 Bldg.Type House.Style  Overall.Qual  Overall.Cond  Year.Built  \
# 0        Norm     Twnhs      1Story             6             5        2005
# 1        Norm      1Fam      1Story             4             5        1970
# 2        Norm      1Fam      SFoyer             5             8        1972
# 3        Norm    Duplex      1Story             5             5        1979
# 4        Norm      1Fam      2Story             9             5        2006
# 5        Norm      1Fam      1Story             4             9        1946
# 6        Norm      1Fam      1Story             8             6        1976
# 7        Norm      1Fam      1Story             4             5        1950
# 8        Norm      1Fam      1Story             7             5        2000
# 9        Norm      1Fam      2Story             4             1        1907
#
#    Year.Remod.Add Roof.Style Roof.Matl Exterior.1st Exterior.2nd Mas.Vnr.Type  \
# 0            2006      Gable   CompShg      VinylSd      VinylSd        Stone
# 1            1970      Gable   CompShg      Plywood      Plywood         None
# 2            2003      Gable   CompShg      WdShing      HdBoard         None
# 3            1979      Gable   CompShg      Plywood      Plywood         None
# 4            2006      Gable   CompShg      VinylSd      VinylSd        Stone
# 5            2001      Gable   CompShg      MetalSd      MetalSd         None
# 6            1976       Shed   WdShngl      Wd Sdng      Wd Sdng         None
# 7            1950      Gable   CompShg      MetalSd      MetalSd         None
# 8            2000      Gable   CompShg      VinylSd      VinylSd      BrkFace
# 9            1950    Gambrel   CompShg      Wd Sdng       Stucco         None
#
#   Mas.Vnr.Area Exter.Qual Exter.Cond Foundation Bsmt.Qual Bsmt.Cond  \
# 0          182         Gd         TA      PConc        Gd        TA
# 1            0         TA         TA     CBlock        TA        TA
# 2            0         TA         Gd     CBlock        Gd        TA
# 3            0         TA         TA       Slab      None      None
# 4          370         TA         TA      PConc        Ex        Gd
# 5            0         TA         Gd     CBlock        Fa        TA
# 6            0         Gd         TA     CBlock        Gd        Gd
# 7            0         TA         TA     CBlock        TA        TA
# 8          244         Gd         TA      PConc        Gd        TA
# 9            0         TA         TA     CBlock        TA        TA
#
#   Bsmt.Exposure BsmtFin.Type.1 BsmtFin.SF.1 BsmtFin.Type.2 BsmtFin.SF.2  \
# 0            Av            ALQ          866            Unf            0
# 1            No            ALQ          804            Rec           78
# 2            Av            GLQ          660            Unf            0
# 3          None           None            0           None            0
# 4            Av            Unf            0            Unf            0
# 5            No            Unf            0            Unf            0
# 6            Gd            LwQ           51            GLQ          915
# 7            No            Unf            0            Unf            0
# 8            Av            GLQ         1400            Unf            0
# 9            No            Rec           73            Unf            0
#
#   Bsmt.Unf.SF Total.Bsmt.SF Heating Heating.QC Central.Air Electrical  \
# 0         436          1302    GasA         Ex           Y      SBrkr
# 1           0           882    GasA         TA           Y      SBrkr
# 2         108           768    GasA         Gd           Y      SBrkr
# 3           0             0    GasA         TA           Y      SBrkr
# 4        1249          1249    GasA         Ex           Y      SBrkr
# 5         560           560    GasA         Ex           Y      FuseA
# 6           0           966    GasA         Ex           Y      SBrkr
# 7         576           576    GasA         Ex           Y      SBrkr
# 8         125          1525    GasA         Ex           Y      SBrkr
# 9         634           707    GasW         TA           N      SBrkr
#
#    X1st.Flr.SF  X2nd.Flr.SF  Low.Qual.Fin.SF  Gr.Liv.Area Bsmt.Full.Bath  \
# 0         1302            0                0         1302              1
# 1          882            0                0          882              1
# 2          768            0                0          768              0
# 3         1535            0                0         1535              0
# 4         1249         1347                0         2596              0
# 5          704            0                0          704              0
# 6         1743            0                0         1743              2
# 7          864            0                0          864              0
# 8         1525            0                0         1525              1
# 9          942          942                0         1884              0
#
#   Bsmt.Half.Bath  Full.Bath  Half.Bath  Bedroom.AbvGr  Kitchen.AbvGr  \
# 0              0          1          1              1              1
# 1              0          1          0              2              1
# 2              1          1          0              2              1
# 3              0          2          0              4              2
# 4              0          3          1              4              1
# 5              1          1          0              2              1
# 6              0          0          1              0              1
# 7              0          1          0              2              1
# 8              0          2          0              3              1
# 9              0          1          1              4              1
#
#   Kitchen.Qual  TotRms.AbvGrd Functional  Fireplaces Fireplace.Qu Garage.Type  \
# 0           Gd              5        Typ           1           Gd      Attchd
# 1           TA              4        Typ           0         None      Attchd
# 2           TA              5        Typ           0         None      Detchd
# 3           TA              8        Typ           0         None      Attchd
# 4           Gd              9        Typ           0         None      Attchd
# 5           Fa              4        Typ           0         None     CarPort
# 6           Gd              5        Typ           2           Fa      Attchd
# 7           TA              5        Typ           0         None      Detchd
# 8           Gd              6        Typ           0         None      Attchd
# 9           TA              7        Typ           0         None        None
#
#   Garage.Yr.Blt Garage.Finish Garage.Cars Garage.Area Garage.Qual Garage.Cond  \
# 0          2005           RFn           2         631          TA          TA
# 1          1970           Fin           2         525          TA          TA
# 2          1974           Fin           1         396          TA          TA
# 3          1979           Unf           2         400          TA          TA
# 4          2006           RFn           3         840          TA          TA
# 5          1946           Unf           1         220          TA          TA
# 6          1976           Fin           2         529          TA          TA
# 7          1952           RFn           1         528          TA          TA
# 8          2000           RFn           2         541          TA          TA
# 9          None          None           0           0        None        None
#
#   Paved.Drive  Wood.Deck.SF  Open.Porch.SF  Enclosed.Porch  X3Ssn.Porch  \
# 0           Y           110             50               0            0
# 1           Y           240              0               0            0
# 2           Y           192              0               0            0
# 3           Y             0              0               0            0
# 4           Y           240            154               0            0
# 5           Y             0              0              24            0
# 6           Y           646              0               0            0
# 7           Y             0              0               0            0
# 8           Y           219             36               0            0
# 9           N             0              0             239            0
#
#    Screen.Porch  Pool.Area Pool.QC  Fence Misc.Feature  Misc.Val  Mo.Sold  \
# 0             0          0    None   None         None         0        8
# 1             0          0    None  MnPrv         None         0        4
# 2             0          0    None  MnPrv         None         0        4
# 3             0          0    None   None         None         0        6
# 4             0          0    None   None         None         0        9
# 5             0          0    None   None         None         0        9
# 6             0          0    None   None         None         0        5
# 7           115          0    None   None         None         0        8
# 8             0          0    None   None         None         0        9
# 9             0          0    None   None         None         0        3
#
#    Yr.Sold Sale.Type Sale.Condition  SalePrice
# 0     2007       New        Partial     204000
# 1     2010       WD          Normal     126000
# 2     2009       WD          Normal     133900
# 3     2009       WD          Alloca     118858
# 4     2006       New        Partial     342643
# 5     2009       WD          Normal      88750
# 6     2007       WD          Normal     279000
# 7     2006       COD         Normal     105000
# 8     2006       WD          Normal     235000
# 9     2010       WD         Abnorml      93369

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 80 columns):
# MS.SubClass        2000 non-null int64
# MS.Zoning          2000 non-null object
# Lot.Frontage       2000 non-null object
# Lot.Area           2000 non-null int64
# Street             2000 non-null object
# Alley              2000 non-null object
# Lot.Shape          2000 non-null object
# Land.Contour       2000 non-null object
# Utilities          2000 non-null object
# Lot.Config         2000 non-null object
# Land.Slope         2000 non-null object
# Neighborhood       2000 non-null object
# Condition.1        2000 non-null object
# Condition.2        2000 non-null object
# Bldg.Type          2000 non-null object
# House.Style        2000 non-null object
# Overall.Qual       2000 non-null int64
# Overall.Cond       2000 non-null int64
# Year.Built         2000 non-null int64
# Year.Remod.Add     2000 non-null int64
# Roof.Style         2000 non-null object
# Roof.Matl          2000 non-null object
# Exterior.1st       2000 non-null object
# Exterior.2nd       2000 non-null object
# Mas.Vnr.Type       1984 non-null object
# Mas.Vnr.Area       2000 non-null object
# Exter.Qual         2000 non-null object
# Exter.Cond         2000 non-null object
# Foundation         2000 non-null object
# Bsmt.Qual          1999 non-null object
# Bsmt.Cond          1999 non-null object
# Bsmt.Exposure      1997 non-null object
# BsmtFin.Type.1     1999 non-null object
# BsmtFin.SF.1       2000 non-null object
# BsmtFin.Type.2     1998 non-null object
# BsmtFin.SF.2       2000 non-null object
# Bsmt.Unf.SF        2000 non-null object
# Total.Bsmt.SF      2000 non-null object
# Heating            2000 non-null object
# Heating.QC         2000 non-null object
# Central.Air        2000 non-null object
# Electrical         2000 non-null object
# X1st.Flr.SF        2000 non-null int64
# X2nd.Flr.SF        2000 non-null int64
# Low.Qual.Fin.SF    2000 non-null int64
# Gr.Liv.Area        2000 non-null int64
# Bsmt.Full.Bath     2000 non-null object
# Bsmt.Half.Bath     2000 non-null object
# Full.Bath          2000 non-null int64
# Half.Bath          2000 non-null int64
# Bedroom.AbvGr      2000 non-null int64
# Kitchen.AbvGr      2000 non-null int64
# Kitchen.Qual       2000 non-null object
# TotRms.AbvGrd      2000 non-null int64
# Functional         2000 non-null object
# Fireplaces         2000 non-null int64
# Fireplace.Qu       2000 non-null object
# Garage.Type        2000 non-null object
# Garage.Yr.Blt      2000 non-null object
# Garage.Finish      1998 non-null object
# Garage.Cars        2000 non-null object
# Garage.Area        2000 non-null object
# Garage.Qual        1999 non-null object
# Garage.Cond        1999 non-null object
# Paved.Drive        2000 non-null object
# Wood.Deck.SF       2000 non-null int64
# Open.Porch.SF      2000 non-null int64
# Enclosed.Porch     2000 non-null int64
# X3Ssn.Porch        2000 non-null int64
# Screen.Porch       2000 non-null int64
# Pool.Area          2000 non-null int64
# Pool.QC            2000 non-null object
# Fence              2000 non-null object
# Misc.Feature       2000 non-null object
# Misc.Val           2000 non-null int64
# Mo.Sold            2000 non-null int64
# Yr.Sold            2000 non-null int64
# Sale.Type          2000 non-null object
# Sale.Condition     2000 non-null object
# SalePrice          2000 non-null int64
# dtypes: int64(26), object(54)
# memory usage: 1.2+ MB

# %% [markdown]
#     Określenie brakujących wartości i ich uzupełnienie

# %%
df.loc[:, (df.isnull().sum()>0)].isnull().sum()
# Out:
# Mas.Vnr.Type      16
# Bsmt.Qual          1
# Bsmt.Cond          1
# Bsmt.Exposure      3
# BsmtFin.Type.1     1
# BsmtFin.Type.2     2
# Garage.Finish      2
# Garage.Qual        1
# Garage.Cond        1
# dtype: int64

# %% [markdown]
# lista kolumn z brakującymi wartościami

# %%
kolumny_puste = list(df.loc[:, (df.isnull().sum()>0)].isnull().sum().index)
kolumny_puste
# Out:
# ['Mas.Vnr.Type',
#  'Bsmt.Qual',
#  'Bsmt.Cond',
#  'Bsmt.Exposure',
#  'BsmtFin.Type.1',
#  'BsmtFin.Type.2',
#  'Garage.Finish',
#  'Garage.Qual',
#  'Garage.Cond']

# %% [markdown]
# brakujących wartości jest mało, dlatego zastąpię je wartościami najczęstszymi

# %%
for kolumna in kolumny_puste:
    df[kolumna] = df[kolumna].fillna(df[kolumna].value_counts().index[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 80 columns):
# MS.SubClass        2000 non-null int64
# MS.Zoning          2000 non-null object
# Lot.Frontage       2000 non-null object
# Lot.Area           2000 non-null int64
# Street             2000 non-null object
# Alley              2000 non-null object
# Lot.Shape          2000 non-null object
# Land.Contour       2000 non-null object
# Utilities          2000 non-null object
# Lot.Config         2000 non-null object
# Land.Slope         2000 non-null object
# Neighborhood       2000 non-null object
# Condition.1        2000 non-null object
# Condition.2        2000 non-null object
# Bldg.Type          2000 non-null object
# House.Style        2000 non-null object
# Overall.Qual       2000 non-null int64
# Overall.Cond       2000 non-null int64
# Year.Built         2000 non-null int64
# Year.Remod.Add     2000 non-null int64
# Roof.Style         2000 non-null object
# Roof.Matl          2000 non-null object
# Exterior.1st       2000 non-null object
# Exterior.2nd       2000 non-null object
# Mas.Vnr.Type       2000 non-null object
# Mas.Vnr.Area       2000 non-null object
# Exter.Qual         2000 non-null object
# Exter.Cond         2000 non-null object
# Foundation         2000 non-null object
# Bsmt.Qual          2000 non-null object
# Bsmt.Cond          2000 non-null object
# Bsmt.Exposure      2000 non-null object
# BsmtFin.Type.1     2000 non-null object
# BsmtFin.SF.1       2000 non-null object
# BsmtFin.Type.2     2000 non-null object
# BsmtFin.SF.2       2000 non-null object
# Bsmt.Unf.SF        2000 non-null object
# Total.Bsmt.SF      2000 non-null object
# Heating            2000 non-null object
# Heating.QC         2000 non-null object
# Central.Air        2000 non-null object
# Electrical         2000 non-null object
# X1st.Flr.SF        2000 non-null int64
# X2nd.Flr.SF        2000 non-null int64
# Low.Qual.Fin.SF    2000 non-null int64
# Gr.Liv.Area        2000 non-null int64
# Bsmt.Full.Bath     2000 non-null object
# Bsmt.Half.Bath     2000 non-null object
# Full.Bath          2000 non-null int64
# Half.Bath          2000 non-null int64
# Bedroom.AbvGr      2000 non-null int64
# Kitchen.AbvGr      2000 non-null int64
# Kitchen.Qual       2000 non-null object
# TotRms.AbvGrd      2000 non-null int64
# Functional         2000 non-null object
# Fireplaces         2000 non-null int64
# Fireplace.Qu       2000 non-null object
# Garage.Type        2000 non-null object
# Garage.Yr.Blt      2000 non-null object
# Garage.Finish      2000 non-null object
# Garage.Cars        2000 non-null object
# Garage.Area        2000 non-null object
# Garage.Qual        2000 non-null object
# Garage.Cond        2000 non-null object
# Paved.Drive        2000 non-null object
# Wood.Deck.SF       2000 non-null int64
# Open.Porch.SF      2000 non-null int64
# Enclosed.Porch     2000 non-null int64
# X3Ssn.Porch        2000 non-null int64
# Screen.Porch       2000 non-null int64
# Pool.Area          2000 non-null int64
# Pool.QC            2000 non-null object
# Fence              2000 non-null object
# Misc.Feature       2000 non-null object
# Misc.Val           2000 non-null int64
# Mo.Sold            2000 non-null int64
# Yr.Sold            2000 non-null int64
# Sale.Type          2000 non-null object
# Sale.Condition     2000 non-null object
# SalePrice          2000 non-null int64
# dtypes: int64(26), object(54)
# memory usage: 1.2+ MB

# %% [markdown]
# Zestawienie typów danych w kolumnach i ilości niepowtarzalnych wartości

# %%
badane_kolumny = df.loc[:, df.dtypes=='object']
typy_danych = pd.concat(
    [pd.concat([badane_kolumny.dtypes, 
                badane_kolumny.nunique(),
                badane_kolumny.isna().sum(),
                (badane_kolumny=='None').sum()
               ], 
               axis =1).transpose(), 
     badane_kolumny.head(), 
     badane_kolumny.tail()], 
    axis=0)
typy_danych
# Out:
#      MS.Zoning Lot.Frontage  Street   Alley Lot.Shape Land.Contour Utilities  \
# 0       object       object  object  object    object       object    object
# 1            7          121       2       3         4            4         1
# 2            0            0       0       0         0            0         0
# 3            0          334       0    1865         0            0         0
# 0           RL           34    Pave    None       Reg          Lvl    AllPub
# 1           RL           70    Pave    None       Reg          Lvl    AllPub
# 2           RL           60    Pave    None       Reg          Lvl    AllPub
# 3           RL           64    Pave    None       Reg          Bnk    AllPub
# 4           RL          111    Pave    None       Reg          Lvl    AllPub
# 1995        RL           80    Pave    None       Reg          Lvl    AllPub
# 1996        RM           35    Pave    None       Reg          Lvl    AllPub
# 1997        RL           76    Pave    None       IR1          Lvl    AllPub
# 1998        RL         None    Pave    None       IR1          Lvl    AllPub
# 1999        FV           34    Pave    None       Reg          Lvl    AllPub
#
#      Lot.Config Land.Slope Neighborhood Condition.1 Condition.2 Bldg.Type  \
# 0        object     object       object      object      object    object
# 1             5          3           27           9           7         5
# 2             0          0            0           0           0         0
# 3             0          0            0           0           0         0
# 0        Inside        Gtl      NridgHt        Norm        Norm     Twnhs
# 1        Corner        Gtl      Nonemes        Norm        Norm      1Fam
# 2        Inside        Gtl      CollgCr        Norm        Norm      1Fam
# 3        Inside        Gtl      SawyerW        Norm        Norm    Duplex
# 4        Corner        Gtl      NridgHt        Norm        Norm      1Fam
# 1995     Inside        Gtl      Nonemes        Norm        Norm      1Fam
# 1996     Inside        Gtl      Edwards        Norm        Norm    TwnhsE
# 1997     Inside        Gtl      SawyerW        Norm        Norm      1Fam
# 1998    CulDSac        Gtl       Sawyer        Norm        Norm      1Fam
# 1999     Inside        Gtl      Somerst        Norm        Norm    TwnhsE
#
#      House.Style Roof.Style Roof.Matl Exterior.1st Exterior.2nd Mas.Vnr.Type  \
# 0         object     object    object       object       object       object
# 1              8          6         7           14           16            5
# 2              0          0         0            0            0            0
# 3              0          0         0            0            0         1232
# 0         1Story      Gable   CompShg      VinylSd      VinylSd        Stone
# 1         1Story      Gable   CompShg      Plywood      Plywood         None
# 2         SFoyer      Gable   CompShg      WdShing      HdBoard         None
# 3         1Story      Gable   CompShg      Plywood      Plywood         None
# 4         2Story      Gable   CompShg      VinylSd      VinylSd        Stone
# 1995        SLvl      Gable   CompShg      BrkFace      Plywood         None
# 1996        SLvl      Gable   CompShg      VinylSd      VinylSd      BrkFace
# 1997      2Story      Gable   CompShg      VinylSd      VinylSd         None
# 1998      SFoyer        Hip   CompShg      Wd Sdng      Wd Sdng         None
# 1999      2Story      Gable   CompShg      MetalSd      MetalSd      BrkFace
#
#      Mas.Vnr.Area Exter.Qual Exter.Cond Foundation Bsmt.Qual Bsmt.Cond  \
# 0          object     object     object     object    object    object
# 1             363          4          4          6         6         6
# 2               0          0          0          0         0         0
# 3              16          0          0          0        52        52
# 0             182         Gd         TA      PConc        Gd        TA
# 1               0         TA         TA     CBlock        TA        TA
# 2               0         TA         Gd     CBlock        Gd        TA
# 3               0         TA         TA       Slab      None      None
# 4             370         TA         TA      PConc        Ex        Gd
# 1995            0         TA         TA     CBlock        Gd        TA
# 1996           80         TA         TA      PConc        Gd        TA
# 1997            0         Gd         TA      PConc        Gd        TA
# 1998            0         TA         TA     CBlock        Gd        TA
# 1999          513         Gd         TA      PConc        Gd        TA
#
#      Bsmt.Exposure BsmtFin.Type.1 BsmtFin.SF.1 BsmtFin.Type.2 BsmtFin.SF.2  \
# 0           object         object       object         object       object
# 1                5              7          817              7          212
# 2                0              0            0              0            0
# 3               52             52            1             52            1
# 0               Av            ALQ          866            Unf            0
# 1               No            ALQ          804            Rec           78
# 2               Av            GLQ          660            Unf            0
# 3             None           None            0           None            0
# 4               Av            Unf            0            Unf            0
# 1995            Av            GLQ          433            Rec           95
# 1996            Gd            GLQ          459            Unf            0
# 1997            No            GLQ          656            Unf            0
# 1998            Av            GLQ          685            Unf            0
# 1999            No            GLQ          507            Unf            0
#
#      Bsmt.Unf.SF Total.Bsmt.SF Heating Heating.QC Central.Air Electrical  \
# 0         object        object  object     object      object     object
# 1            928           871       6          5           2          4
# 2              0             0       0          0           0          0
# 3              1             1       0          0           0          0
# 0            436          1302    GasA         Ex           Y      SBrkr
# 1              0           882    GasA         TA           Y      SBrkr
# 2            108           768    GasA         Gd           Y      SBrkr
# 3              0             0    GasA         TA           Y      SBrkr
# 4           1249          1249    GasA         Ex           Y      SBrkr
# 1995           0           528    GasA         TA           Y      SBrkr
# 1996          88           547    GasA         Ex           Y      SBrkr
# 1997         300           956    GasA         Ex           Y      SBrkr
# 1998         173           858    GasA         TA           Y      SBrkr
# 1999         249           756    GasA         Ex           Y      SBrkr
#
#      Bsmt.Full.Bath Bsmt.Half.Bath Kitchen.Qual Functional Fireplace.Qu  \
# 0            object         object       object     object       object
# 1                 5              4            4          7            6
# 2                 0              0            0          0            0
# 3                 1              1            0          0          980
# 0                 1              0           Gd        Typ           Gd
# 1                 1              0           TA        Typ         None
# 2                 0              1           TA        Typ         None
# 3                 0              0           TA        Typ         None
# 4                 0              0           Gd        Typ         None
# 1995              1              0           TA        Typ         None
# 1996              1              0           TA        Typ         None
# 1997              1              0           Gd        Typ         None
# 1998              1              0           TA        Typ         None
# 1999              1              0           Gd        Typ         None
#
#      Garage.Type Garage.Yr.Blt Garage.Finish Garage.Cars Garage.Area  \
# 0         object        object        object      object      object
# 1              7           101             4           7         531
# 2              0             0             0           0           0
# 3            110           112           110           1           1
# 0         Attchd          2005           RFn           2         631
# 1         Attchd          1970           Fin           2         525
# 2         Detchd          1974           Fin           1         396
# 3         Attchd          1979           Unf           2         400
# 4         Attchd          2006           RFn           3         840
# 1995      Attchd          1959           RFn           1         288
# 1996     Basment          2005           RFn           2         525
# 1997     BuiltIn          2004           RFn           2         618
# 1998      Detchd          1983           Unf           2         576
# 1999      Detchd          2000           Unf           2         440
#
#      Garage.Qual Garage.Cond Paved.Drive Pool.QC   Fence Misc.Feature  \
# 0         object      object      object  object  object       object
# 1              6           6           3       5       5            5
# 2              0           0           0       0       0            0
# 3            111         111           0    1989    1605         1926
# 0             TA          TA           Y    None    None         None
# 1             TA          TA           Y    None   MnPrv         None
# 2             TA          TA           Y    None   MnPrv         None
# 3             TA          TA           Y    None    None         None
# 4             TA          TA           Y    None    None         None
# 1995          TA          TA           Y    None    GdWo         None
# 1996          TA          TA           Y    None    None         None
# 1997          TA          TA           Y    None    None         None
# 1998          TA          TA           Y    None    None         None
# 1999          TA          TA           Y    None    None         None
#
#      Sale.Type Sale.Condition
# 0       object         object
# 1           10              6
# 2            0              0
# 3            0              0
# 0          New        Partial
# 1          WD          Normal
# 2          WD          Normal
# 3          WD          Alloca
# 4          New        Partial
# 1995       WD          Normal
# 1996       WD          Normal
# 1997       WD          Normal
# 1998       WD          Normal
# 1999       WD          Normal

# %%
kolumny_object_na_binarne = ['Lot.Frontage', 'Mas.Vnr.Area', 'BsmtFin.SF.1', 'BsmtFin.SF.2', 
                             'Bsmt.Unf.SF', 'Total.Bsmt.SF', 'Bsmt.Full.Bath', 'Bsmt.Half.Bath', 
                             'Garage.Yr.Blt', 'Garage.Cars', 'Garage.Area']

# %% [markdown]
# zamiana w tych kolumnach wartości 'None' na 0 i wartości tekstowych na liczbowe

# %%
for kolumna_zmieniana in kolumny_object_na_binarne:
    df.loc[df[kolumna_zmieniana]=='None', kolumna_zmieniana] = '0'
    df[kolumna_zmieniana] = df[kolumna_zmieniana].astype('int64')

# %% [markdown]
#     Przygotowanie danych do regresji poprzez kodowanie zmiennych tekstowych do kategorii liczbowych

# %%
kolumny_tekst = list(df.select_dtypes(include='object').columns)
print(kolumny_tekst)
print(len(kolumny_tekst))
# Out:
# ['MS.Zoning', 'Street', 'Alley', 'Lot.Shape', 'Land.Contour', 'Utilities', 'Lot.Config', 'Land.Slope', 'Neighborhood', 'Condition.1', 'Condition.2', 'Bldg.Type', 'House.Style', 'Roof.Style', 'Roof.Matl', 'Exterior.1st', 'Exterior.2nd', 'Mas.Vnr.Type', 'Exter.Qual', 'Exter.Cond', 'Foundation', 'Bsmt.Qual', 'Bsmt.Cond', 'Bsmt.Exposure', 'BsmtFin.Type.1', 'BsmtFin.Type.2', 'Heating', 'Heating.QC', 'Central.Air', 'Electrical', 'Kitchen.Qual', 'Functional', 'Fireplace.Qu', 'Garage.Type', 'Garage.Finish', 'Garage.Qual', 'Garage.Cond', 'Paved.Drive', 'Pool.QC', 'Fence', 'Misc.Feature', 'Sale.Type', 'Sale.Condition']
# 43

# %% [markdown]
# kodowanie zmiennych tekstowych do liczbowych w celu regresji

# %%
for kolumna_zmieniana in kolumny_tekst:
    kolumna_zamieniona = pd.get_dummies(df[kolumna_zmieniana], prefix=kolumna_zmieniana)
    df = df.drop(kolumna_zmieniana, axis=1)
    df = df.join(kolumna_zamieniona)

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 306 columns):
# MS.SubClass               int64
# Lot.Frontage              int64
# Lot.Area                  int64
# Overall.Qual              int64
# Overall.Cond              int64
# Year.Built                int64
# Year.Remod.Add            int64
# Mas.Vnr.Area              int64
# BsmtFin.SF.1              int64
# BsmtFin.SF.2              int64
# Bsmt.Unf.SF               int64
# Total.Bsmt.SF             int64
# X1st.Flr.SF               int64
# X2nd.Flr.SF               int64
# Low.Qual.Fin.SF           int64
# Gr.Liv.Area               int64
# Bsmt.Full.Bath            int64
# Bsmt.Half.Bath            int64
# Full.Bath                 int64
# Half.Bath                 int64
# Bedroom.AbvGr             int64
# Kitchen.AbvGr             int64
# TotRms.AbvGrd             int64
# Fireplaces                int64
# Garage.Yr.Blt             int64
# Garage.Cars               int64
# Garage.Area               int64
# Wood.Deck.SF              int64
# Open.Porch.SF             int64
# Enclosed.Porch            int64
# X3Ssn.Porch               int64
# Screen.Porch              int64
# Pool.Area                 int64
# Misc.Val                  int64
# Mo.Sold                   int64
# Yr.Sold                   int64
# SalePrice                 int64
# MS.Zoning_A (agr)         uint8
# MS.Zoning_C (all)         uint8
# MS.Zoning_FV              uint8
# MS.Zoning_I (all)         uint8
# MS.Zoning_RH              uint8
# MS.Zoning_RL              uint8
# MS.Zoning_RM              uint8
# Street_Grvl               uint8
# Street_Pave               uint8
# Alley_Grvl                uint8
# Alley_None                uint8
# Alley_Pave                uint8
# Lot.Shape_IR1             uint8
# Lot.Shape_IR2             uint8
# Lot.Shape_IR3             uint8
# Lot.Shape_Reg             uint8
# Land.Contour_Bnk          uint8
# Land.Contour_HLS          uint8
# Land.Contour_Low          uint8
# Land.Contour_Lvl          uint8
# Utilities_AllPub          uint8
# Lot.Config_Corner         uint8
# Lot.Config_CulDSac        uint8
# Lot.Config_FR2            uint8
# Lot.Config_FR3            uint8
# Lot.Config_Inside         uint8
# Land.Slope_Gtl            uint8
# Land.Slope_Mod            uint8
# Land.Slope_Sev            uint8
# Neighborhood_Blmngtn      uint8
# Neighborhood_Blueste      uint8
# Neighborhood_BrDale       uint8
# Neighborhood_BrkSide      uint8
# Neighborhood_ClearCr      uint8
# Neighborhood_CollgCr      uint8
# Neighborhood_Crawfor      uint8
# Neighborhood_Edwards      uint8
# Neighborhood_Gilbert      uint8
# Neighborhood_Greens       uint8
# Neighborhood_GrnHill      uint8
# Neighborhood_IDOTRR       uint8
# Neighborhood_MeadowV      uint8
# Neighborhood_Mitchel      uint8
# Neighborhood_NPkVill      uint8
# Neighborhood_NWAmes       uint8
# Neighborhood_NoRidge      uint8
# Neighborhood_Nonemes      uint8
# Neighborhood_NridgHt      uint8
# Neighborhood_OldTown      uint8
# Neighborhood_SWISU        uint8
# Neighborhood_Sawyer       uint8
# Neighborhood_SawyerW      uint8
# Neighborhood_Somerst      uint8
# Neighborhood_StoneBr      uint8
# Neighborhood_Timber       uint8
# Neighborhood_Veenker      uint8
# Condition.1_Artery        uint8
# Condition.1_Feedr         uint8
# Condition.1_Norm          uint8
# Condition.1_PosA          uint8
# Condition.1_PosN          uint8
# Condition.1_RRAe          uint8
# Condition.1_RRAn          uint8
# Condition.1_RRNe          uint8
# Condition.1_RRNn          uint8
# Condition.2_Artery        uint8
# Condition.2_Feedr         uint8
# Condition.2_Norm          uint8
# Condition.2_PosA          uint8
# Condition.2_PosN          uint8
# Condition.2_RRAn          uint8
# Condition.2_RRNn          uint8
# Bldg.Type_1Fam            uint8
# Bldg.Type_2fmCon          uint8
# Bldg.Type_Duplex          uint8
# Bldg.Type_Twnhs           uint8
# Bldg.Type_TwnhsE          uint8
# House.Style_1.5Fin        uint8
# House.Style_1.5Unf        uint8
# House.Style_1Story        uint8
# House.Style_2.5Fin        uint8
# House.Style_2.5Unf        uint8
# House.Style_2Story        uint8
# House.Style_SFoyer        uint8
# House.Style_SLvl          uint8
# Roof.Style_Flat           uint8
# Roof.Style_Gable          uint8
# Roof.Style_Gambrel        uint8
# Roof.Style_Hip            uint8
# Roof.Style_Mansard        uint8
# Roof.Style_Shed           uint8
# Roof.Matl_ClyTile         uint8
# Roof.Matl_CompShg         uint8
# Roof.Matl_Membran         uint8
# Roof.Matl_Metal           uint8
# Roof.Matl_Tar&Grv         uint8
# Roof.Matl_WdShake         uint8
# Roof.Matl_WdShngl         uint8
# Exterior.1st_AsbShng      uint8
# Exterior.1st_AsphShn      uint8
# Exterior.1st_BrkComm      uint8
# Exterior.1st_BrkFace      uint8
# Exterior.1st_CBlock       uint8
# Exterior.1st_CemntBd      uint8
# Exterior.1st_HdBoard      uint8
# Exterior.1st_MetalSd      uint8
# Exterior.1st_Plywood      uint8
# Exterior.1st_Stone        uint8
# Exterior.1st_Stucco       uint8
# Exterior.1st_VinylSd      uint8
# Exterior.1st_Wd Sdng      uint8
# Exterior.1st_WdShing      uint8
# Exterior.2nd_AsbShng      uint8
# Exterior.2nd_AsphShn      uint8
# Exterior.2nd_Brk Cmn      uint8
# Exterior.2nd_BrkFace      uint8
# Exterior.2nd_CBlock       uint8
# Exterior.2nd_CmentBd      uint8
# Exterior.2nd_HdBoard      uint8
# Exterior.2nd_ImStucc      uint8
# Exterior.2nd_MetalSd      uint8
# Exterior.2nd_Other        uint8
# Exterior.2nd_Plywood      uint8
# Exterior.2nd_Stone        uint8
# Exterior.2nd_Stucco       uint8
# Exterior.2nd_VinylSd      uint8
# Exterior.2nd_Wd Sdng      uint8
# Exterior.2nd_Wd Shng      uint8
# Mas.Vnr.Type_BrkCmn       uint8
# Mas.Vnr.Type_BrkFace      uint8
# Mas.Vnr.Type_CBlock       uint8
# Mas.Vnr.Type_None         uint8
# Mas.Vnr.Type_Stone        uint8
# Exter.Qual_Ex             uint8
# Exter.Qual_Fa             uint8
# Exter.Qual_Gd             uint8
# Exter.Qual_TA             uint8
# Exter.Cond_Ex             uint8
# Exter.Cond_Fa             uint8
# Exter.Cond_Gd             uint8
# Exter.Cond_TA             uint8
# Foundation_BrkTil         uint8
# Foundation_CBlock         uint8
# Foundation_PConc          uint8
# Foundation_Slab           uint8
# Foundation_Stone          uint8
# Foundation_Wood           uint8
# Bsmt.Qual_Ex              uint8
# Bsmt.Qual_Fa              uint8
# Bsmt.Qual_Gd              uint8
# Bsmt.Qual_None            uint8
# Bsmt.Qual_Po              uint8
# Bsmt.Qual_TA              uint8
# Bsmt.Cond_Ex              uint8
# Bsmt.Cond_Fa              uint8
# Bsmt.Cond_Gd              uint8
# Bsmt.Cond_None            uint8
# Bsmt.Cond_Po              uint8
# Bsmt.Cond_TA              uint8
# Bsmt.Exposure_Av          uint8
# Bsmt.Exposure_Gd          uint8
# Bsmt.Exposure_Mn          uint8
# Bsmt.Exposure_No          uint8
# Bsmt.Exposure_None        uint8
# BsmtFin.Type.1_ALQ        uint8
# BsmtFin.Type.1_BLQ        uint8
# BsmtFin.Type.1_GLQ        uint8
# BsmtFin.Type.1_LwQ        uint8
# BsmtFin.Type.1_None       uint8
# BsmtFin.Type.1_Rec        uint8
# BsmtFin.Type.1_Unf        uint8
# BsmtFin.Type.2_ALQ        uint8
# BsmtFin.Type.2_BLQ        uint8
# BsmtFin.Type.2_GLQ        uint8
# BsmtFin.Type.2_LwQ        uint8
# BsmtFin.Type.2_None       uint8
# BsmtFin.Type.2_Rec        uint8
# BsmtFin.Type.2_Unf        uint8
# Heating_Floor             uint8
# Heating_GasA              uint8
# Heating_GasW              uint8
# Heating_Grav              uint8
# Heating_OthW              uint8
# Heating_Wall              uint8
# Heating.QC_Ex             uint8
# Heating.QC_Fa             uint8
# Heating.QC_Gd             uint8
# Heating.QC_Po             uint8
# Heating.QC_TA             uint8
# Central.Air_N             uint8
# Central.Air_Y             uint8
# Electrical_FuseA          uint8
# Electrical_FuseF          uint8
# Electrical_FuseP          uint8
# Electrical_SBrkr          uint8
# Kitchen.Qual_Ex           uint8
# Kitchen.Qual_Fa           uint8
# Kitchen.Qual_Gd           uint8
# Kitchen.Qual_TA           uint8
# Functional_Maj1           uint8
# Functional_Maj2           uint8
# Functional_Min1           uint8
# Functional_Min2           uint8
# Functional_Mod            uint8
# Functional_Sev            uint8
# Functional_Typ            uint8
# Fireplace.Qu_Ex           uint8
# Fireplace.Qu_Fa           uint8
# Fireplace.Qu_Gd           uint8
# Fireplace.Qu_None         uint8
# Fireplace.Qu_Po           uint8
# Fireplace.Qu_TA           uint8
# Garage.Type_2Types        uint8
# Garage.Type_Attchd        uint8
# Garage.Type_Basment       uint8
# Garage.Type_BuiltIn       uint8
# Garage.Type_CarPort       uint8
# Garage.Type_Detchd        uint8
# Garage.Type_None          uint8
# Garage.Finish_Fin         uint8
# Garage.Finish_None        uint8
# Garage.Finish_RFn         uint8
# Garage.Finish_Unf         uint8
# Garage.Qual_Ex            uint8
# Garage.Qual_Fa            uint8
# Garage.Qual_Gd            uint8
# Garage.Qual_None          uint8
# Garage.Qual_Po            uint8
# Garage.Qual_TA            uint8
# Garage.Cond_Ex            uint8
# Garage.Cond_Fa            uint8
# Garage.Cond_Gd            uint8
# Garage.Cond_None          uint8
# Garage.Cond_Po            uint8
# Garage.Cond_TA            uint8
# Paved.Drive_N             uint8
# Paved.Drive_P             uint8
# Paved.Drive_Y             uint8
# Pool.QC_Ex                uint8
# Pool.QC_Fa                uint8
# Pool.QC_Gd                uint8
# Pool.QC_None              uint8
# Pool.QC_TA                uint8
# Fence_GdPrv               uint8
# Fence_GdWo                uint8
# Fence_MnPrv               uint8
# Fence_MnWw                uint8
# Fence_None                uint8
# Misc.Feature_Gar2         uint8
# Misc.Feature_None         uint8
# Misc.Feature_Othr         uint8
# Misc.Feature_Shed         uint8
# Misc.Feature_TenC         uint8
# Sale.Type_COD             uint8
# Sale.Type_CWD             uint8
# Sale.Type_Con             uint8
# Sale.Type_ConLD           uint8
# Sale.Type_ConLI           uint8
# Sale.Type_ConLw           uint8
# Sale.Type_New             uint8
# Sale.Type_Oth             uint8
# Sale.Type_VWD             uint8
# Sale.Type_WD              uint8
# Sale.Condition_Abnorml    uint8
# Sale.Condition_AdjLand    uint8
# Sale.Condition_Alloca     uint8
# Sale.Condition_Family     uint8
# Sale.Condition_Normal     uint8
# Sale.Condition_Partial    uint8
# dtypes: int64(37), uint8(269)
# memory usage: 1.1 MB

# %% [markdown]
#     Modelowanie

# %% [markdown]
# podział na zbiory testowe i treningowe

# %%
X = df.drop(["SalePrice"], axis=1)
y = df["SalePrice"].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0)

# %% [markdown]
# regresja liniowa

# %%
linear_regressor = LinearRegression()
linear_regressor.fit(X_train, y_train)
lin_y_pred = linear_regressor.predict(X_test)
mae_linear = metrics.mean_absolute_error(y_test, lin_y_pred)
rmse_linear = np.sqrt(metrics.mean_squared_error(y_test, lin_y_pred))
r2_score_linear = metrics.r2_score(y_test, lin_y_pred)
print(f"Regresja liniowa:\n MAE={mae_linear}\n RMSE={rmse_linear}\n r2 score={r2_score_linear}")
# Out:
# Regresja liniowa:
#  MAE=16034.56550109188
#  RMSE=24900.450669835012
#  r2 score=0.9072265122910987

# %% [markdown]
# regresja ridge

# %%
ridge = Ridge()
parameters = {'alpha': [0.01, 0.1, 1, 5, 10, 20, 40, 80, 100, 250, 500, 1000]}
ridge_regressor = GridSearchCV(ridge, parameters, cv=5)
ridge_regressor.fit(X_train, y_train)
print(f"Najlepszy wybrany parametr {ridge_regressor.best_params_}")
print(f"Score dla parametru alpha {ridge_regressor.best_score_}")
ridge_regressor = Ridge(alpha=ridge_regressor.best_params_['alpha'])
ridge_regressor.fit(X_train, y_train)
ridge_y_pred = ridge_regressor.predict(X_test)
mae_ridge = metrics.mean_absolute_error(y_test, ridge_y_pred)
rmse_ridge = np.sqrt(metrics.mean_squared_error(y_test, ridge_y_pred))
r2_score_ridge = metrics.r2_score(y_test, ridge_y_pred)
print(f"Regresja ridge:\n MAE={mae_ridge}\n RMSE={rmse_ridge}\n r2 score={r2_score_ridge}")
# Out:
# Najlepszy wybrany parametr {'alpha': 20}
# Score dla parametru alpha 0.8461000200976937
# Regresja ridge:
#  MAE=15777.630476918108
#  RMSE=23007.159884826033
#  r2 score=0.920798120084954

# %% [markdown]
# regresja lasso

# %%
lasso = Lasso()
parameters = {'alpha': [20, 60, 100, 250, 500, 750, 1000]}
lasso_regressor = GridSearchCV(lasso, parameters, cv=5)
lasso_regressor.fit(X_train,y_train)
lasso_regressor.best_params_
print(f"Najlepszy wybrany parametr {lasso_regressor.best_params_}")
print(f"Score dla parametru alpha {lasso_regressor.best_score_}")
lasso_regressor = Lasso(alpha=lasso_regressor.best_params_['alpha'])
lasso_regressor.fit(X_train, y_train)
lasso_y_pred = lasso_regressor.predict(X_test)
mae_lasso = metrics.mean_absolute_error(y_test, lasso_y_pred)
rmse_lasso = np.sqrt(metrics.mean_squared_error(y_test, lasso_y_pred))
r2_score_lasso = metrics.r2_score(y_test, lasso_y_pred)
print(f"Regresja lasso.\n MAE={mae_lasso}\n RMSE={rmse_lasso}\n r2 score={r2_score_lasso}")
# Out:
# Najlepszy wybrany parametr {'alpha': 100}
# Score dla parametru alpha 0.8626439358986071
# Regresja lasso.
#  MAE=14587.588583190118
#  RMSE=21144.013704739427
#  r2 score=0.9331064364750775

# %% [markdown]
# porównanie wynikow w formie tabeli

# %%
dane = [['Liniowa',mae_linear, rmse_linear, r2_score_linear],['Ridge',mae_ridge, rmse_ridge, r2_score_ridge],['Lasso',mae_lasso, rmse_lasso, r2_score_lasso]]
tabelka = pd.DataFrame(dane,columns=['Model regresji','MAE', 'RMSE', 'R2 Score'])
tabelka.set_index('Model regresji', inplace=True)
tabelka
# Out:
#                          MAE          RMSE  R2 Score
# Model regresji
# Liniowa         16034.565501  24900.450670  0.907227
# Ridge           15777.630477  23007.159885  0.920798
# Lasso           14587.588583  21144.013705  0.933106

# %% [markdown]
# porównanie wyników w formie wykresów

# %%
objects = ('Linear', 'Ridge', 'Lasso')
y_pos = np.arange(len(objects))
MAE = [mae_linear, mae_ridge, mae_lasso]
RMSE = [rmse_linear, rmse_ridge, rmse_lasso]
R2= [r2_score_linear, r2_score_ridge, r2_score_lasso]

f, axs = plt.subplots(1,3,figsize=(22,4))

plt.subplot(1,3,1)
plt.bar(y_pos, MAE, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Wartość')
plt.title('MAE')
plt.ylim(13500, 16500)

plt.subplot(1,3,2)
plt.bar(y_pos, RMSE, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.title('RMSE')
plt.ylim(20500,25500)

plt.subplot(1,3,3)
plt.bar(y_pos, R2, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.title('R2')
plt.ylim(0.89,0.935)

plt.show()

# %%
f, axs = plt.subplots(3,1,figsize=(20,10))

plt.subplot(3,1,1)
plot_x = np.linspace(0, lin_y_pred.size, lin_y_pred.size)
plt.plot(plot_x, lin_y_pred, 'o', color='grey', label='model')
plt.plot(plot_x, y_test, 'o', color='black', label='rzeczywista')
plt.ylabel('cena')
plt.title('regresja liniowa')
plt.legend(loc='upper left')

plt.subplot(3,1,2)
plot_x = np.linspace(0, lin_y_pred.size, lin_y_pred.size)
plt.plot(plot_x, ridge_y_pred, 'o', color='grey', label='model')
plt.plot(plot_x, y_test, 'o', color='black', label='rzeczywista')
plt.ylabel('cena')
plt.title('regresja Ridge')
plt.legend(loc='upper left')

plt.subplot(3,1,3)
plot_x = np.linspace(0, lin_y_pred.size, lin_y_pred.size)
plt.plot(plot_x, lasso_y_pred, 'o', color='grey', label='model')
plt.plot(plot_x, y_test, 'o', color='black',label='rzeczywista')
plt.ylabel('cena')
plt.title('regresja Lasso')
plt.legend(loc='upper left')

plt.show()

# %% [markdown]
#     Konkluzje

# %% [markdown]
# Najlepszym modelem jest __Lasso__, który najlepiej przewiduje cenę nieruchomości a następnie __Ridge__. Model __regresji liniowej__ trochę gorzej przewiduje ceny nieruchomoćci, tym niemniej R2 Score (siła korelacji pomiędzy modelem a rzeczywistymi danymi) dla wszystkich modeli przekracza 0,90 co jest wartością akceptowalną.
